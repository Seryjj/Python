# %%
# Дана функция f(x) = sin(x)^2 - cos(x)^2

# 1. Определить корни (найти такие х, при которых f(x) = 0) - корни уравнения  f(x) = 0

# 2. Найти интервалы, на которых функция возрастает (решить неравенства где производная больше или меньше нуля)

# 3. Найти интервалы, на которых функция убывает

# 4. Построить график

# 5. Вычислить вершину (найти производню и приравнять к нулю)

# 6. Определить промежутки, на котором f > 0 (Найти такие x, при которых f(х) > 0) неравенствo f(x) > 0

# 7. Определить промежутки, на котором f < 0 ( Найти такие x, при которых f(х) < 0) неравенствo f(x) < 0

# %%
from sympy import *

# 4. Построить график
x = Symbol('x')
f = sin(x)**2-cos(x)**2
p1 = plot(f, show=False)
p1.show()

# %%
# 1. Определить корни
ans = solve(f,x)
print(ans)
for i in ans:
    print(i.evalf())
# Out:
# [-pi/4, pi/4]
# -0.785398163397448
# 0.785398163397448

# %%
# 6. Определить промежутки, на котором f > 0 (Найти такие x, при которых f(х) > 0) неравенствo f(x) > 0

pprint(solveset(f > 0, x, domain=S.Reals), use_unicode=True)
# Out:
# ⎛π  3⋅π⎞
# ⎜─, ───⎟
# ⎝4   4 ⎠

# %%
# 7. Определить промежутки, на котором f < 0 ( Найти такие x, при которых f(х) < 0) неравенствo f(x) < 0

pprint(solveset(f < 0, x, domain=S.Reals), use_unicode=True)
# Out:
# ⎡   π⎞   ⎛3⋅π   ⎞
# ⎢0, ─⎟ ∪ ⎜───, π⎟
# ⎣   4⎠   ⎝ 4    ⎠

# %%
# 5. Вычислить вершину (найти производню и приравнять к нулю)

diff_f = diff(f,x)
print(diff_f)
solve(diff_f,x)
# Out:
# 4*sin(x)*cos(x)
# [0, pi/2, pi, 3*pi/2]

# %%
# 2. Найти интервалы, на которых функция возрастает

pprint(solveset(diff_f > 0, x, domain=S.Reals), use_unicode=True)
# Out:
# ⎛   π⎞
# ⎜0, ─⎟
# ⎝   2⎠

# %%
# 3. Найти интервалы, на которых функция убывает

pprint(solveset(diff_f < 0, x, domain=S.Reals), use_unicode=True)
# Out:
# ⎛π   ⎞
# ⎜─, π⎟
# ⎝2   ⎠

# %%
# Out:
# [48970, 47985, 47010, 46045, 45090, 44145, 43210, 42285, 41370, 40465, 39570, 38685, 37810, 36945, 36090, 35245, 34410, 33585, 32770, 31965, 31170, 30385, 29610, 28845, 28090, 27345, 26610, 25885, 25170, 24465, 23770, 23085, 22410, 21745, 21090, 20445, 19810, 19185, 18570, 17965, 17370, 16785, 16210, 15645, 15090, 14545, 14010, 13485, 12970, 12465, 11970, 11485, 11010, 10545, 10090, 9645, 9210, 8785, 8370, 7965, 7570, 7185, 6810, 6445, 6090, 5745, 5410, 5085, 4770, 4465, 4170, 3885, 3610, 3345, 3090, 2845, 2610, 2385, 2170, 1965, 1770, 1585, 1410, 1245, 1090, 945, 810, 685, 570, 465, 370, 285, 210, 145, 90, 45, 10, -15, -30, -35, -30, -15, 10, 45, 90, 145, 210, 285, 370, 465, 570, 685, 810, 945, 1090, 1245, 1410, 1585, 1770, 1965, 2170, 2385, 2610, 2845, 3090, 3345, 3610, 3885, 4170, 4465, 4770, 5085, 5410, 5745, 6090, 6445, 6810, 7185, 7570, 7965, 8370, 8785, 9210, 9645, 10090, 10545, 11010, 11485, 11970, 12465, 12970, 13485, 14010, 14545, 15090, 15645, 16210, 16785, 17370, 17965, 18570, 19185, 19810, 20445, 21090, 21745, 22410, 23085, 23770, 24465, 25170, 25885, 26610, 27345, 28090, 28845, 29610, 30385, 31170, 31965, 32770, 33585, 34410, 35245, 36090, 36945, 37810, 38685, 39570, 40465, 41370, 42285, 43210, 44145, 45090, 46045, 47010, 47985, 48970, 49965]
